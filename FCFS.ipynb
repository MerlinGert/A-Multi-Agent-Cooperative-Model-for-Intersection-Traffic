# %%
import heapq
import matplotlib
from matplotlib import patches
from matplotlib.patches import Rectangle
from matplotlib import animation
from matplotlib.animation import FuncAnimation
import tkinter as tk
from tkinter import ttk
from matplotlib.widgets import Button
matplotlib.use('TkAgg')
import matplotlib.pyplot as plt
import random
import numpy as np
import itertools
import numpy as np
import gym
from gym import spaces

current_time = 0

class Gridworld:
    def __init__(self, width, height):
        self.width = width
        self.height = height
        self.walls = []
        self.start = (0, 0)
        self.goal = (width - 1, height - 1)
        self.setup_central_crossroad_and_parking_area()

    def in_bounds(self, id):
        (x, y) = id
        return 0 <= x < self.width and 0 <= y < self.height

    def passable(self, id):
        return id not in self.walls

    def neighbors(self, id):
        (x, y) = id
        results = [(x + 1, y), (x, y - 1), (x - 1, y), (x, y + 1)]
        results = filter(self.in_bounds, results)
        results = filter(self.passable, results)
        return list(results)

    def setup_central_crossroad(self):
        crossroad_size = 4
        mid_x = self.width // 2
        mid_y = self.height // 2
        crossroad_start_x = mid_x - crossroad_size // 2
        crossroad_end_x = crossroad_start_x + crossroad_size
        crossroad_start_y = mid_y - crossroad_size // 2
        crossroad_end_y = crossroad_start_y + crossroad_size
        self.walls = [pos for pos in self.walls if not (crossroad_start_x <= pos[0] < crossroad_end_x and crossroad_start_y <= pos[1] < crossroad_end_y)]

    def setup_central_crossroad_and_parking_area(self):
        crossroad_size = 4
        parking_area_size = 5
        mid_x = self.width // 2
        mid_y = self.height // 2
        self.crossroad_start_x = mid_x - crossroad_size // 2
        self.crossroad_end_x = self.crossroad_start_x + crossroad_size
        self.crossroad_start_y = mid_y - crossroad_size // 2
        self.crossroad_end_y = self.crossroad_start_y + crossroad_size
        self.parking_area_start_x = mid_x - parking_area_size // 2
        self.parking_area_end_x = self.parking_area_start_x + parking_area_size
        self.parking_area_start_y = mid_y - parking_area_size // 2
        self.parking_area_end_y = self.parking_area_start_y + parking_area_size

    def is_in_crossroad(self, pos):
        x, y = pos
        return (self.crossroad_start_x <= x < self.crossroad_end_x and
                self.crossroad_start_y <= y < self.crossroad_end_y)

    def is_in_parking_area(self, pos):
        x, y = pos
        return (self.parking_area_start_x <= x < self.parking_area_end_x and
                self.parking_area_start_y <= y < self.parking_area_end_y)

    def has_vehicle_in_crossroad(self, current_vehicle_pos, vehicles):
        for vehicle in vehicles:
            if vehicle.pos != current_vehicle_pos and self.is_in_crossroad(vehicle.pos):
                return True
        return False

def heuristic(a, b):
    (x1, y1) = a
    (x2, y2) = b
    return abs(x1 - x2) + abs(y1 - y2)

class PriorityQueue:
    def __init__(self):
        self.elements = []

    def empty(self):
        return len(self.elements) == 0

    def put(self, item, priority):
        heapq.heappush(self.elements, (priority, item))

    def get(self):
        return heapq.heappop(self.elements)[1]

def setup_crossroad_obstacles(grid, obstacle_size, road_width):
    grid.walls = []
    mid_x_start = grid.width // 2 - road_width // 2
    mid_x_end = mid_x_start + road_width
    mid_y_start = grid.height // 2 - road_width // 2
    mid_y_end = mid_y_start + road_width
    for x in range(grid.width):
        for y in range(grid.height):
            in_obstacle = (x < obstacle_size and y < obstacle_size) or \
                          (x < obstacle_size and y >= grid.height - obstacle_size) or \
                          (x >= grid.width - obstacle_size and y < obstacle_size) or \
                          (x >= grid.width - obstacle_size and y >= grid.height - obstacle_size)
            in_road = mid_x_start <= x < mid_x_end or mid_y_start <= y < mid_y_end
            if in_obstacle and not in_road:
                grid.walls.append((x, y))

def draw_grid_with_crossroad(grid, ax):
    ax.set_aspect('equal')
    ax.set_xlim(0, grid.width)
    ax.set_ylim(0, grid.height)
    for x, y in grid.walls:
        ax.fill([x, x + 1, x + 1, x], [y, y, y + 1, y + 1], "black")
    for x in range(grid.width + 1):
        ax.plot([x, x], [0, grid.height], color="gray", lw=0.5)
    for y in range(grid.height + 1):
        ax.plot([0, grid.width], [y, y], color="gray", lw=0.5)
    plt.gca().invert_yaxis()

def setup_roadway_entry_exit_points(grid, road_width):
    mid_x, mid_y = grid.width // 2, grid.height // 2
    lane_offset = road_width // 4
    entry_exit_points = {
        'south_to_north': {
            'start': [(mid_x+1, grid.height - 1)],
            'end': [(mid_x+1, 0)]
        },
        'north_to_south': {
            'start': [(mid_x-1, 0)],
            'end': [(mid_x-1, grid.height - 1)]
        },
        'east_to_west': {
            'start': [(grid.width - 1, mid_y-1)],
            'end': [(0, mid_y-1)]
        },
        'west_to_east': {
            'start': [(0, mid_y+1)],
            'end': [(grid.width - 1, mid_y+1)]
        },
    }
    return entry_exit_points

def distance_between(pos1, pos2):
    return ((pos1[0] - pos2[0])**2 + (pos1[1] - pos2[1])**2)**0.5
# Out:
# Vehicle vehicle_south_to_north broadcasting message: {'sender': 'vehicle_south_to_north', 'current_position': (11, 19), 'future_positions': [(11, 19), (11, 18), (11, 17), (11, 16), (11, 15), (11, 14)], 'priority': 1716927221.5099542, 'waiting': False}
# Vehicle vehicle_south_to_north broadcasting message: {'sender': 'vehicle_south_to_north', 'current_position': (11, 19), 'future_positions': [(11, 19), (11, 18), (11, 17), (11, 16), (11, 15), (11, 14)], 'priority': 1716927221.5099494, 'waiting': False}
# Vehicle vehicle_south_to_north broadcasting message: {'sender': 'vehicle_south_to_north', 'current_position': (11, 18), 'future_positions': [(11, 18), (11, 17), (11, 16), (11, 15), (11, 14), (11, 13)], 'priority': 1716927221.7731128, 'waiting': False}
# Vehicle vehicle_south_to_north broadcasting message: {'sender': 'vehicle_south_to_north', 'current_position': (11, 18), 'future_positions': [(11, 18), (11, 17), (11, 16), (11, 15), (11, 14), (11, 13)], 'priority': 1716927221.773111, 'waiting': False}
# Vehicle vehicle_south_to_north broadcasting message: {'sender': 'vehicle_south_to_north', 'current_position': (11, 17), 'future_positions': [(11, 17), (11, 16), (11, 15), (11, 14), (11, 13), (11, 12)], 'priority': 1716927222.0655046, 'waiting': False}
# Vehicle vehicle_south_to_north broadcasting message: {'sender': 'vehicle_south_to_north', 'current_position': (11, 17), 'future_positions': [(11, 17), (11, 16), (11, 15), (11, 14), (11, 13), (11, 12)], 'priority': 1716927222.065509, 'waiting': False}
# Vehicle vehicle_south_to_north broadcasting message: {'sender': 'vehicle_south_to_north', 'current_position': (11, 16), 'future_positions': [(11, 16), (11, 15), (11, 14), (11, 13), (11, 12), (11, 11)], 'priority': 1716927222.3923013, 'waiting': False}
# Vehicle vehicle_south_to_north broadcasting message: {'sender': 'vehicle_south_to_north', 'current_position': (11, 16), 'future_positions': [(11, 16), (11, 15), (11, 14), (11, 13), (11, 12), (11, 11)], 'priority': 1716927222.3923018, 'waiting': False}
# Vehicle vehicle_south_to_north broadcasting message: {'sender': 'vehicle_south_to_north', 'current_position': (11, 15), 'future_positions': [(11, 15), (11, 14), (11, 13), (11, 12), (11, 11), (11, 10)], 'priority': 1716927222.7599502, 'waiting': False}
# Vehicle vehicle_south_to_north broadcasting message: {'sender': 'vehicle_south_to_north', 'current_position': (11, 15), 'future_positions': [(11, 15), (11, 14), (11, 13), (11, 12), (11, 11), (11, 10)], 'priority': 1716927222.759948, 'waiting': False}
# Vehicle vehicle_south_to_north broadcasting message: {'sender': 'vehicle_south_to_north', 'current_position': (11, 14), 'future_positions': [(11, 14), (11, 13), (11, 12), (11, 11), (11, 10), (11, 9)], 'priority': 1716927223.1766183, 'waiting': False}
# Vehicle vehicle_2 broadcasting message: {'sender': 'vehicle_2', 'current_position': (11, 19), 'future_positions': [(11, 19), (11, 18), (11, 17), (11, 16), (11, 15), (11, 14)], 'priority': 1716927222.9379525, 'waiting': False}
# Vehicle vehicle_3 broadcasting message: {'sender': 'vehicle_3', 'current_position': (19, 9), 'future_positions': [(19, 9), (18, 9), (17, 9), (16, 9), (15, 9), (14, 9)], 'priority': 1716927222.9379497, 'waiting': False}
# Vehicle vehicle_4 broadcasting message: {'sender': 'vehicle_4', 'current_position': (9, 0), 'future_positions': [(9, 0), (9, 1), (9, 2), (9, 3), (9, 4), (9, 5)], 'priority': 1716927222.9379504, 'waiting': False}
# Vehicle vehicle_south_to_north broadcasting message: {'sender': 'vehicle_south_to_north', 'current_position': (11, 14), 'future_positions': [(11, 14), (11, 13), (11, 12), (11, 11), (11, 10), (11, 9)], 'priority': 1716927223.1766195, 'waiting': True}
# Vehicle vehicle_2 broadcasting message: {'sender': 'vehicle_2', 'current_position': (11, 19), 'future_positions': [(11, 19), (11, 18), (11, 17), (11, 16), (11, 15), (11, 14)], 'priority': 1716927222.9379513, 'waiting': True}
# Vehicle vehicle_3 broadcasting message: {'sender': 'vehicle_3', 'current_position': (19, 9), 'future_positions': [(19, 9), (18, 9), (17, 9), (16, 9), (15, 9), (14, 9)], 'priority': 1716927222.9379535, 'waiting': False}
# Vehicle vehicle_4 broadcasting message: {'sender': 'vehicle_4', 'current_position': (9, 0), 'future_positions': [(9, 0), (9, 1), (9, 2), (9, 3), (9, 4), (9, 5)], 'priority': 1716927222.9379456, 'waiting': False}
# Vehicle vehicle_south_to_north broadcasting message: {'sender': 'vehicle_south_to_north', 'current_position': (11, 13), 'future_positions': [(11, 13), (11, 12), (11, 11), (11, 10), (11, 9), (11, 8)], 'priority': 1716927223.652809, 'waiting': False}
# Vehicle vehicle_2 broadcasting message: {'sender': 'vehicle_2', 'current_position': (11, 18), 'future_positions': [(11, 18), (11, 17), (11, 16), (11, 15), (11, 14), (11, 13)], 'priority': 1716927223.2011077, 'waiting': False}
# Vehicle vehicle_3 broadcasting message: {'sender': 'vehicle_3', 'current_position': (18, 9), 'future_positions': [(18, 9), (17, 9), (16, 9), (15, 9), (14, 9), (13, 9)], 'priority': 1716927223.2011018, 'waiting': False}
# Vehicle vehicle_4 broadcasting message: {'sender': 'vehicle_4', 'current_position': (9, 1), 'future_positions': [(9, 1), (9, 2), (9, 3), (9, 4), (9, 5), (9, 6)], 'priority': 1716927223.20111, 'waiting': False}
# Vehicle vehicle_south_to_north broadcasting message: {'sender': 'vehicle_south_to_north', 'current_position': (11, 13), 'future_positions': [(11, 13), (11, 12), (11, 11), (11, 10), (11, 9), (11, 8)], 'priority': 1716927223.652807, 'waiting': True}
# Vehicle vehicle_2 broadcasting message: {'sender': 'vehicle_2', 'current_position': (11, 18), 'future_positions': [(11, 18), (11, 17), (11, 16), (11, 15), (11, 14), (11, 13)], 'priority': 1716927223.2011068, 'waiting': True}
# Vehicle vehicle_3 broadcasting message: {'sender': 'vehicle_3', 'current_position': (18, 9), 'future_positions': [(18, 9), (17, 9), (16, 9), (15, 9), (14, 9), (13, 9)], 'priority': 1716927223.2011085, 'waiting': False}
# Vehicle vehicle_4 broadcasting message: {'sender': 'vehicle_4', 'current_position': (9, 1), 'future_positions': [(9, 1), (9, 2), (9, 3), (9, 4), (9, 5), (9, 6)], 'priority': 1716927223.2011058, 'waiting': False}
# Vehicle vehicle_south_to_north broadcasting message: {'sender': 'vehicle_south_to_north', 'current_position': (11, 12), 'future_positions': [(11, 12), (11, 11), (11, 10), (11, 9), (11, 8), (11, 7)], 'priority': 1716927224.2022579, 'waiting': False}
# Vehicle vehicle_2 broadcasting message: {'sender': 'vehicle_2', 'current_position': (11, 17), 'future_positions': [(11, 17), (11, 16), (11, 15), (11, 14), (11, 13), (11, 12)], 'priority': 1716927223.4935014, 'waiting': False}
# Vehicle vehicle_3 broadcasting message: {'sender': 'vehicle_3', 'current_position': (17, 9), 'future_positions': [(17, 9), (16, 9), (15, 9), (14, 9), (13, 9), (12, 9)], 'priority': 1716927223.4935024, 'waiting': False}
# Vehicle vehicle_4 broadcasting message: {'sender': 'vehicle_4', 'current_position': (9, 2), 'future_positions': [(9, 2), (9, 3), (9, 4), (9, 5), (9, 6), (9, 7)], 'priority': 1716927223.4935083, 'waiting': False}
# Vehicle vehicle_south_to_north broadcasting message: {'sender': 'vehicle_south_to_north', 'current_position': (11, 12), 'future_positions': [(11, 12), (11, 11), (11, 10), (11, 9), (11, 8), (11, 7)], 'priority': 1716927224.202258, 'waiting': True}
# Vehicle vehicle_2 broadcasting message: {'sender': 'vehicle_2', 'current_position': (11, 17), 'future_positions': [(11, 17), (11, 16), (11, 15), (11, 14), (11, 13), (11, 12)], 'priority': 1716927223.4935048, 'waiting': True}
# Vehicle vehicle_3 broadcasting message: {'sender': 'vehicle_3', 'current_position': (17, 9), 'future_positions': [(17, 9), (16, 9), (15, 9), (14, 9), (13, 9), (12, 9)], 'priority': 1716927223.4935021, 'waiting': False}
# Vehicle vehicle_4 broadcasting message: {'sender': 'vehicle_4', 'current_position': (9, 2), 'future_positions': [(9, 2), (9, 3), (9, 4), (9, 5), (9, 6), (9, 7)], 'priority': 1716927223.4934993, 'waiting': False}
# Vehicle vehicle_south_to_north broadcasting message: {'sender': 'vehicle_south_to_north', 'current_position': (11, 11), 'future_positions': [(11, 11), (11, 10), (11, 9), (11, 8), (11, 7), (11, 6)], 'priority': 1716927224.8432894, 'waiting': False}
# Vehicle vehicle_2 broadcasting message: {'sender': 'vehicle_2', 'current_position': (11, 16), 'future_positions': [(11, 16), (11, 15), (11, 14), (11, 13), (11, 12), (11, 11)], 'priority': 1716927223.8203, 'waiting': False}
# Vehicle vehicle_3 broadcasting message: {'sender': 'vehicle_3', 'current_position': (16, 9), 'future_positions': [(16, 9), (15, 9), (14, 9), (13, 9), (12, 9), (11, 9)], 'priority': 1716927223.8202991, 'waiting': False}
# Vehicle vehicle_4 broadcasting message: {'sender': 'vehicle_4', 'current_position': (9, 3), 'future_positions': [(9, 3), (9, 4), (9, 5), (9, 6), (9, 7), (9, 8)], 'priority': 1716927223.820299, 'waiting': False}
# Vehicle vehicle_south_to_north broadcasting message: {'sender': 'vehicle_south_to_north', 'current_position': (11, 11), 'future_positions': [(11, 11), (11, 10), (11, 9), (11, 8), (11, 7), (11, 6)], 'priority': 1716927224.843287, 'waiting': True}
# Vehicle vehicle_2 broadcasting message: {'sender': 'vehicle_2', 'current_position': (11, 16), 'future_positions': [(11, 16), (11, 15), (11, 14), (11, 13), (11, 12), (11, 11)], 'priority': 1716927223.820303, 'waiting': True}
# Vehicle vehicle_3 broadcasting message: {'sender': 'vehicle_3', 'current_position': (16, 9), 'future_positions': [(16, 9), (15, 9), (14, 9), (13, 9), (12, 9), (11, 9)], 'priority': 1716927223.8203046, 'waiting': True}
# Vehicle vehicle_4 broadcasting message: {'sender': 'vehicle_4', 'current_position': (9, 3), 'future_positions': [(9, 3), (9, 4), (9, 5), (9, 6), (9, 7), (9, 8)], 'priority': 1716927223.8203065, 'waiting': False}
# Vehicle vehicle_south_to_north broadcasting message: {'sender': 'vehicle_south_to_north', 'current_position': (11, 10), 'future_positions': [(11, 10), (11, 9), (11, 8), (11, 7), (11, 6), (11, 5)], 'priority': 1716927225.6008573, 'waiting': False}
# Vehicle vehicle_2 broadcasting message: {'sender': 'vehicle_2', 'current_position': (11, 15), 'future_positions': [(11, 15), (11, 14), (11, 13), (11, 12), (11, 11), (11, 10)], 'priority': 1716927224.1879447, 'waiting': False}
# Vehicle vehicle_3 broadcasting message: {'sender': 'vehicle_3', 'current_position': (15, 9), 'future_positions': [(15, 9), (14, 9), (13, 9), (12, 9), (11, 9), (10, 9)], 'priority': 1716927224.1879508, 'waiting': False}
# Vehicle vehicle_4 broadcasting message: {'sender': 'vehicle_4', 'current_position': (9, 4), 'future_positions': [(9, 4), (9, 5), (9, 6), (9, 7), (9, 8), (9, 9)], 'priority': 1716927224.1879528, 'waiting': False}
# Vehicle vehicle_south_to_north broadcasting message: {'sender': 'vehicle_south_to_north', 'current_position': (11, 10), 'future_positions': [(11, 10), (11, 9), (11, 8), (11, 7), (11, 6), (11, 5)], 'priority': 1716927225.600863, 'waiting': True}
# Vehicle vehicle_2 broadcasting message: {'sender': 'vehicle_2', 'current_position': (11, 15), 'future_positions': [(11, 15), (11, 14), (11, 13), (11, 12), (11, 11), (11, 10)], 'priority': 1716927224.1879523, 'waiting': True}
# Vehicle vehicle_3 broadcasting message: {'sender': 'vehicle_3', 'current_position': (15, 9), 'future_positions': [(15, 9), (14, 9), (13, 9), (12, 9), (11, 9), (10, 9)], 'priority': 1716927224.1879447, 'waiting': True}
# Vehicle vehicle_4 broadcasting message: {'sender': 'vehicle_4', 'current_position': (9, 4), 'future_positions': [(9, 4), (9, 5), (9, 6), (9, 7), (9, 8), (9, 9)], 'priority': 1716927224.187945, 'waiting': False}
# Vehicle vehicle_south_to_north broadcasting message: {'sender': 'vehicle_south_to_north', 'current_position': (11, 9), 'future_positions': [(11, 9), (11, 8), (11, 7), (11, 6), (11, 5), (11, 4)], 'priority': 1716927226.509953, 'waiting': False}
# Vehicle vehicle_2 broadcasting message: {'sender': 'vehicle_2', 'current_position': (11, 14), 'future_positions': [(11, 14), (11, 13), (11, 12), (11, 11), (11, 10), (11, 9)], 'priority': 1716927224.6046138, 'waiting': False}
# Vehicle vehicle_3 broadcasting message: {'sender': 'vehicle_3', 'current_position': (14, 9), 'future_positions': [(14, 9), (13, 9), (12, 9), (11, 9), (10, 9), (9, 9)], 'priority': 1716927224.6046174, 'waiting': False}
# Vehicle vehicle_4 broadcasting message: {'sender': 'vehicle_4', 'current_position': (9, 5), 'future_positions': [(9, 5), (9, 6), (9, 7), (9, 8), (9, 9), (9, 10)], 'priority': 1716927224.6046119, 'waiting': False}
# Vehicle vehicle_5 broadcasting message: {'sender': 'vehicle_5', 'current_position': (19, 9), 'future_positions': [(19, 9), (18, 9), (17, 9), (16, 9), (15, 9), (14, 9)], 'priority': 1716927224.3638885, 'waiting': False}
# Vehicle vehicle_6 broadcasting message: {'sender': 'vehicle_6', 'current_position': (9, 0), 'future_positions': [(9, 0), (9, 1), (9, 2), (9, 3), (9, 4), (9, 5)], 'priority': 1716927224.363887, 'waiting': False}
# Vehicle vehicle_south_to_north broadcasting message: {'sender': 'vehicle_south_to_north', 'current_position': (11, 9), 'future_positions': [(11, 9), (11, 8), (11, 7), (11, 6), (11, 5), (11, 4)], 'priority': 1716927226.5099475, 'waiting': True}
# Vehicle vehicle_2 broadcasting message: {'sender': 'vehicle_2', 'current_position': (11, 14), 'future_positions': [(11, 14), (11, 13), (11, 12), (11, 11), (11, 10), (11, 9)], 'priority': 1716927224.604612, 'waiting': True}
# Vehicle vehicle_3 broadcasting message: {'sender': 'vehicle_3', 'current_position': (14, 9), 'future_positions': [(14, 9), (13, 9), (12, 9), (11, 9), (10, 9), (9, 9)], 'priority': 1716927224.6046174, 'waiting': True}
# Vehicle vehicle_4 broadcasting message: {'sender': 'vehicle_4', 'current_position': (9, 5), 'future_positions': [(9, 5), (9, 6), (9, 7), (9, 8), (9, 9), (9, 10)], 'priority': 1716927224.6046126, 'waiting': True}
# Vehicle vehicle_5 broadcasting message: {'sender': 'vehicle_5', 'current_position': (19, 9), 'future_positions': [(19, 9), (18, 9), (17, 9), (16, 9), (15, 9), (14, 9)], 'priority': 1716927224.3638928, 'waiting': True}
# Vehicle vehicle_6 broadcasting message: {'sender': 'vehicle_6', 'current_position': (9, 0), 'future_positions': [(9, 0), (9, 1), (9, 2), (9, 3), (9, 4), (9, 5)], 'priority': 1716927224.3638859, 'waiting': True}
# Vehicle vehicle_south_to_north broadcasting message: {'sender': 'vehicle_south_to_north', 'current_position': (11, 8), 'future_positions': [(11, 8), (11, 7), (11, 6), (11, 5), (11, 4), (11, 3)], 'priority': 1716927227.621063, 'waiting': False}
# Vehicle vehicle_2 broadcasting message: {'sender': 'vehicle_2', 'current_position': (11, 13), 'future_positions': [(11, 13), (11, 12), (11, 11), (11, 10), (11, 9), (11, 8)], 'priority': 1716927225.0808096, 'waiting': False}
# Vehicle vehicle_3 broadcasting message: {'sender': 'vehicle_3', 'current_position': (13, 9), 'future_positions': [(13, 9), (12, 9), (11, 9), (10, 9), (9, 9), (8, 9)], 'priority': 1716927225.080809, 'waiting': False}
# Vehicle vehicle_4 broadcasting message: {'sender': 'vehicle_4', 'current_position': (9, 6), 'future_positions': [(9, 6), (9, 7), (9, 8), (9, 9), (9, 10), (9, 11)], 'priority': 1716927225.080804, 'waiting': False}
# Vehicle vehicle_5 broadcasting message: {'sender': 'vehicle_5', 'current_position': (18, 9), 'future_positions': [(18, 9), (17, 9), (16, 9), (15, 9), (14, 9), (13, 9)], 'priority': 1716927224.627042, 'waiting': False}
# Vehicle vehicle_6 broadcasting message: {'sender': 'vehicle_6', 'current_position': (9, 1), 'future_positions': [(9, 1), (9, 2), (9, 3), (9, 4), (9, 5), (9, 6)], 'priority': 1716927224.6270514, 'waiting': False}
# Vehicle vehicle_south_to_north broadcasting message: {'sender': 'vehicle_south_to_north', 'current_position': (11, 8), 'future_positions': [(11, 8), (11, 7), (11, 6), (11, 5), (11, 4), (11, 3)], 'priority': 1716927227.6210618, 'waiting': True}
# Vehicle vehicle_2 broadcasting message: {'sender': 'vehicle_2', 'current_position': (11, 13), 'future_positions': [(11, 13), (11, 12), (11, 11), (11, 10), (11, 9), (11, 8)], 'priority': 1716927225.080802, 'waiting': True}
# Vehicle vehicle_3 broadcasting message: {'sender': 'vehicle_3', 'current_position': (13, 9), 'future_positions': [(13, 9), (12, 9), (11, 9), (10, 9), (9, 9), (8, 9)], 'priority': 1716927225.0808039, 'waiting': True}
# Vehicle vehicle_4 broadcasting message: {'sender': 'vehicle_4', 'current_position': (9, 6), 'future_positions': [(9, 6), (9, 7), (9, 8), (9, 9), (9, 10), (9, 11)], 'priority': 1716927225.0808086, 'waiting': True}
# Vehicle vehicle_5 broadcasting message: {'sender': 'vehicle_5', 'current_position': (18, 9), 'future_positions': [(18, 9), (17, 9), (16, 9), (15, 9), (14, 9), (13, 9)], 'priority': 1716927224.6270454, 'waiting': True}
# Vehicle vehicle_6 broadcasting message: {'sender': 'vehicle_6', 'current_position': (9, 1), 'future_positions': [(9, 1), (9, 2), (9, 3), (9, 4), (9, 5), (9, 6)], 'priority': 1716927224.6270437, 'waiting': True}
# Vehicle vehicle_south_to_north broadcasting message: {'sender': 'vehicle_south_to_north', 'current_position': (11, 7), 'future_positions': [(11, 7), (11, 6), (11, 5), (11, 4), (11, 3), (11, 2)], 'priority': 1716927229.0099547, 'waiting': False}
# Vehicle vehicle_2 broadcasting message: {'sender': 'vehicle_2', 'current_position': (11, 12), 'future_positions': [(11, 12), (11, 11), (11, 10), (11, 9), (11, 8), (11, 7)], 'priority': 1716927225.630253, 'waiting': False}
# Vehicle vehicle_3 broadcasting message: {'sender': 'vehicle_3', 'current_position': (12, 9), 'future_positions': [(12, 9), (11, 9), (10, 9), (9, 9), (8, 9), (7, 9)], 'priority': 1716927225.630254, 'waiting': False}
# Vehicle vehicle_4 broadcasting message: {'sender': 'vehicle_4', 'current_position': (9, 7), 'future_positions': [(9, 7), (9, 8), (9, 9), (9, 10), (9, 11), (9, 12)], 'priority': 1716927225.6302514, 'waiting': False}
# Vehicle vehicle_5 broadcasting message: {'sender': 'vehicle_5', 'current_position': (17, 9), 'future_positions': [(17, 9), (16, 9), (15, 9), (14, 9), (13, 9), (12, 9)], 'priority': 1716927224.9194472, 'waiting': False}
# Vehicle vehicle_6 broadcasting message: {'sender': 'vehicle_6', 'current_position': (9, 2), 'future_positions': [(9, 2), (9, 3), (9, 4), (9, 5), (9, 6), (9, 7)], 'priority': 1716927224.9194407, 'waiting': False}
# Vehicle vehicle_south_to_north broadcasting message: {'sender': 'vehicle_south_to_north', 'current_position': (11, 7), 'future_positions': [(11, 7), (11, 6), (11, 5), (11, 4), (11, 3), (11, 2)], 'priority': 1716927229.0099523, 'waiting': True}
# Vehicle vehicle_2 broadcasting message: {'sender': 'vehicle_2', 'current_position': (11, 12), 'future_positions': [(11, 12), (11, 11), (11, 10), (11, 9), (11, 8), (11, 7)], 'priority': 1716927225.6302607, 'waiting': True}
# Vehicle vehicle_3 broadcasting message: {'sender': 'vehicle_3', 'current_position': (12, 9), 'future_positions': [(12, 9), (11, 9), (10, 9), (9, 9), (8, 9), (7, 9)], 'priority': 1716927225.6302547, 'waiting': True}
# Vehicle vehicle_4 broadcasting message: {'sender': 'vehicle_4', 'current_position': (9, 7), 'future_positions': [(9, 7), (9, 8), (9, 9), (9, 10), (9, 11), (9, 12)], 'priority': 1716927225.6302583, 'waiting': True}
# Vehicle vehicle_5 broadcasting message: {'sender': 'vehicle_5', 'current_position': (17, 9), 'future_positions': [(17, 9), (16, 9), (15, 9), (14, 9), (13, 9), (12, 9)], 'priority': 1716927224.9194422, 'waiting': True}
# Vehicle vehicle_6 broadcasting message: {'sender': 'vehicle_6', 'current_position': (9, 2), 'future_positions': [(9, 2), (9, 3), (9, 4), (9, 5), (9, 6), (9, 7)], 'priority': 1716927224.9194403, 'waiting': True}
# Vehicle vehicle_south_to_north broadcasting message: {'sender': 'vehicle_south_to_north', 'current_position': (11, 6), 'future_positions': [(11, 6), (11, 5), (11, 4), (11, 3), (11, 2), (11, 1)], 'priority': 1716927230.7956662, 'waiting': False}
# Vehicle vehicle_2 broadcasting message: {'sender': 'vehicle_2', 'current_position': (11, 11), 'future_positions': [(11, 11), (11, 10), (11, 9), (11, 8), (11, 7), (11, 6)], 'priority': 1716927226.2712786, 'waiting': False}
# Vehicle vehicle_3 broadcasting message: {'sender': 'vehicle_3', 'current_position': (11, 9), 'future_positions': [(11, 9), (10, 9), (9, 9), (8, 9), (7, 9), (6, 9)], 'priority': 1716927226.2712803, 'waiting': False}
# Vehicle vehicle_4 broadcasting message: {'sender': 'vehicle_4', 'current_position': (9, 8), 'future_positions': [(9, 8), (9, 9), (9, 10), (9, 11), (9, 12), (9, 13)], 'priority': 1716927226.2712789, 'waiting': False}
# Vehicle vehicle_5 broadcasting message: {'sender': 'vehicle_5', 'current_position': (16, 9), 'future_positions': [(16, 9), (15, 9), (14, 9), (13, 9), (12, 9), (11, 9)], 'priority': 1716927225.2462459, 'waiting': False}
# Vehicle vehicle_6 broadcasting message: {'sender': 'vehicle_6', 'current_position': (9, 3), 'future_positions': [(9, 3), (9, 4), (9, 5), (9, 6), (9, 7), (9, 8)], 'priority': 1716927225.2462385, 'waiting': False}
# Vehicle vehicle_south_to_north broadcasting message: {'sender': 'vehicle_south_to_north', 'current_position': (11, 6), 'future_positions': [(11, 6), (11, 5), (11, 4), (11, 3), (11, 2), (11, 1)], 'priority': 1716927230.7956674, 'waiting': True}
# Vehicle vehicle_2 broadcasting message: {'sender': 'vehicle_2', 'current_position': (11, 11), 'future_positions': [(11, 11), (11, 10), (11, 9), (11, 8), (11, 7), (11, 6)], 'priority': 1716927226.2712836, 'waiting': True}
# Vehicle vehicle_3 broadcasting message: {'sender': 'vehicle_3', 'current_position': (11, 9), 'future_positions': [(11, 9), (10, 9), (9, 9), (8, 9), (7, 9), (6, 9)], 'priority': 1716927226.271279, 'waiting': True}
# Vehicle vehicle_4 broadcasting message: {'sender': 'vehicle_4', 'current_position': (9, 8), 'future_positions': [(9, 8), (9, 9), (9, 10), (9, 11), (9, 12), (9, 13)], 'priority': 1716927226.2712824, 'waiting': True}
# Vehicle vehicle_5 broadcasting message: {'sender': 'vehicle_5', 'current_position': (16, 9), 'future_positions': [(16, 9), (15, 9), (14, 9), (13, 9), (12, 9), (11, 9)], 'priority': 1716927225.2462406, 'waiting': True}
# Vehicle vehicle_6 broadcasting message: {'sender': 'vehicle_6', 'current_position': (9, 3), 'future_positions': [(9, 3), (9, 4), (9, 5), (9, 6), (9, 7), (9, 8)], 'priority': 1716927225.2462387, 'waiting': True}
# Vehicle vehicle_south_to_north broadcasting message: {'sender': 'vehicle_south_to_north', 'current_position': (11, 5), 'future_positions': [(11, 5), (11, 4), (11, 3), (11, 2), (11, 1), (11, 0)], 'priority': 1716927233.1766214, 'waiting': False}
# Vehicle vehicle_2 broadcasting message: {'sender': 'vehicle_2', 'current_position': (11, 11), 'future_positions': [(11, 11), (11, 10), (11, 9), (11, 8), (11, 7), (11, 6)], 'priority': 1716927226.27128, 'waiting': True}
# Vehicle vehicle_3 broadcasting message: {'sender': 'vehicle_3', 'current_position': (10, 9), 'future_positions': [(10, 9), (9, 9), (8, 9), (7, 9), (6, 9), (5, 9)], 'priority': 1716927227.0288558, 'waiting': False}
# Vehicle vehicle_4 broadcasting message: {'sender': 'vehicle_4', 'current_position': (9, 9), 'future_positions': [(9, 9), (9, 10), (9, 11), (9, 12), (9, 13), (9, 14)], 'priority': 1716927227.0288608, 'waiting': False}
# Vehicle vehicle_5 broadcasting message: {'sender': 'vehicle_5', 'current_position': (15, 9), 'future_positions': [(15, 9), (14, 9), (13, 9), (12, 9), (11, 9), (10, 9)], 'priority': 1716927225.6138859, 'waiting': False}
# Vehicle vehicle_6 broadcasting message: {'sender': 'vehicle_6', 'current_position': (9, 4), 'future_positions': [(9, 4), (9, 5), (9, 6), (9, 7), (9, 8), (9, 9)], 'priority': 1716927225.6138911, 'waiting': False}
# Vehicle vehicle_south_to_north broadcasting message: {'sender': 'vehicle_south_to_north', 'current_position': (11, 5), 'future_positions': [(11, 5), (11, 4), (11, 3), (11, 2), (11, 1), (11, 0)], 'priority': 1716927233.176623, 'waiting': False}
# Vehicle vehicle_2 broadcasting message: {'sender': 'vehicle_2', 'current_position': (11, 11), 'future_positions': [(11, 11), (11, 10), (11, 9), (11, 8), (11, 7), (11, 6)], 'priority': 1716927226.2712846, 'waiting': True}
# Vehicle vehicle_3 broadcasting message: {'sender': 'vehicle_3', 'current_position': (10, 9), 'future_positions': [(10, 9), (9, 9), (8, 9), (7, 9), (6, 9), (5, 9)], 'priority': 1716927227.0288618, 'waiting': True}
# Vehicle vehicle_4 broadcasting message: {'sender': 'vehicle_4', 'current_position': (9, 9), 'future_positions': [(9, 9), (9, 10), (9, 11), (9, 12), (9, 13), (9, 14)], 'priority': 1716927227.0288603, 'waiting': True}
# Vehicle vehicle_5 broadcasting message: {'sender': 'vehicle_5', 'current_position': (15, 9), 'future_positions': [(15, 9), (14, 9), (13, 9), (12, 9), (11, 9), (10, 9)], 'priority': 1716927225.6138926, 'waiting': True}
# Vehicle vehicle_6 broadcasting message: {'sender': 'vehicle_6', 'current_position': (9, 4), 'future_positions': [(9, 4), (9, 5), (9, 6), (9, 7), (9, 8), (9, 9)], 'priority': 1716927225.6138875, 'waiting': True}
# Vehicle vehicle_south_to_north broadcasting message: {'sender': 'vehicle_south_to_north', 'current_position': (11, 4), 'future_positions': [(11, 4), (11, 3), (11, 2), (11, 1), (11, 0), (11, -1)], 'priority': 1716927236.5099528, 'waiting': False}
# Vehicle vehicle_2 broadcasting message: {'sender': 'vehicle_2', 'current_position': (11, 10), 'future_positions': [(11, 10), (11, 9), (11, 8), (11, 7), (11, 6), (11, 5)], 'priority': 1716927227.0288563, 'waiting': False}
# Vehicle vehicle_3 broadcasting message: {'sender': 'vehicle_3', 'current_position': (10, 9), 'future_positions': [(10, 9), (9, 9), (8, 9), (7, 9), (6, 9), (5, 9)], 'priority': 1716927227.028856, 'waiting': True}
# Vehicle vehicle_4 broadcasting message: {'sender': 'vehicle_4', 'current_position': (9, 10), 'future_positions': [(9, 10), (9, 11), (9, 12), (9, 13), (9, 14), (9, 15)], 'priority': 1716927227.9379504, 'waiting': False}
# Vehicle vehicle_5 broadcasting message: {'sender': 'vehicle_5', 'current_position': (14, 9), 'future_positions': [(14, 9), (13, 9), (12, 9), (11, 9), (10, 9), (9, 9)], 'priority': 1716927226.030558, 'waiting': False}
# Vehicle vehicle_6 broadcasting message: {'sender': 'vehicle_6', 'current_position': (9, 5), 'future_positions': [(9, 5), (9, 6), (9, 7), (9, 8), (9, 9), (9, 10)], 'priority': 1716927226.030554, 'waiting': False}
# Vehicle vehicle_7 broadcasting message: {'sender': 'vehicle_7', 'current_position': (0, 11), 'future_positions': [(0, 11), (1, 11), (2, 11), (3, 11), (4, 11), (5, 11)], 'priority': 1716927225.7932818, 'waiting': False}
# Vehicle vehicle_8 broadcasting message: {'sender': 'vehicle_8', 'current_position': (9, 0), 'future_positions': [(9, 0), (9, 1), (9, 2), (9, 3), (9, 4), (9, 5)], 'priority': 1716927225.793273, 'waiting': False}
# Vehicle vehicle_south_to_north broadcasting message: {'sender': 'vehicle_south_to_north', 'current_position': (11, 4), 'future_positions': [(11, 4), (11, 3), (11, 2), (11, 1), (11, 0), (11, -1)], 'priority': 1716927236.5099561, 'waiting': False}
# Vehicle vehicle_2 broadcasting message: {'sender': 'vehicle_2', 'current_position': (11, 10), 'future_positions': [(11, 10), (11, 9), (11, 8), (11, 7), (11, 6), (11, 5)], 'priority': 1716927227.0288575, 'waiting': True}
# Vehicle vehicle_3 broadcasting message: {'sender': 'vehicle_3', 'current_position': (10, 9), 'future_positions': [(10, 9), (9, 9), (8, 9), (7, 9), (6, 9), (5, 9)], 'priority': 1716927227.0288622, 'waiting': True}
# Vehicle vehicle_4 broadcasting message: {'sender': 'vehicle_4', 'current_position': (9, 10), 'future_positions': [(9, 10), (9, 11), (9, 12), (9, 13), (9, 14), (9, 15)], 'priority': 1716927227.9379506, 'waiting': True}
# Vehicle vehicle_5 broadcasting message: {'sender': 'vehicle_5', 'current_position': (14, 9), 'future_positions': [(14, 9), (13, 9), (12, 9), (11, 9), (10, 9), (9, 9)], 'priority': 1716927226.0305529, 'waiting': True}
# Vehicle vehicle_6 broadcasting message: {'sender': 'vehicle_6', 'current_position': (9, 5), 'future_positions': [(9, 5), (9, 6), (9, 7), (9, 8), (9, 9), (9, 10)], 'priority': 1716927226.0305517, 'waiting': True}
# Vehicle vehicle_7 broadcasting message: {'sender': 'vehicle_7', 'current_position': (0, 11), 'future_positions': [(0, 11), (1, 11), (2, 11), (3, 11), (4, 11), (5, 11)], 'priority': 1716927225.7932773, 'waiting': False}
# Vehicle vehicle_8 broadcasting message: {'sender': 'vehicle_8', 'current_position': (9, 0), 'future_positions': [(9, 0), (9, 1), (9, 2), (9, 3), (9, 4), (9, 5)], 'priority': 1716927225.7932808, 'waiting': True}
# Vehicle vehicle_south_to_north broadcasting message: {'sender': 'vehicle_south_to_north', 'current_position': (11, 3), 'future_positions': [(11, 3), (11, 2), (11, 1), (11, 0), (11, -1), (11, -2)], 'priority': 1716927241.5099516, 'waiting': False}
# Vehicle vehicle_2 broadcasting message: {'sender': 'vehicle_2', 'current_position': (11, 9), 'future_positions': [(11, 9), (11, 8), (11, 7), (11, 6), (11, 5), (11, 4)], 'priority': 1716927227.9379482, 'waiting': False}
# Vehicle vehicle_3 broadcasting message: {'sender': 'vehicle_3', 'current_position': (9, 9), 'future_positions': [(9, 9), (8, 9), (7, 9), (6, 9), (5, 9), (4, 9)], 'priority': 1716927227.937945, 'waiting': False}
# Vehicle vehicle_4 broadcasting message: {'sender': 'vehicle_4', 'current_position': (9, 11), 'future_positions': [(9, 11), (9, 12), (9, 13), (9, 14), (9, 15), (9, 16)], 'priority': 1716927229.0490646, 'waiting': False}
# Vehicle vehicle_5 broadcasting message: {'sender': 'vehicle_5', 'current_position': (14, 9), 'future_positions': [(14, 9), (13, 9), (12, 9), (11, 9), (10, 9), (9, 9)], 'priority': 1716927226.030557, 'waiting': True}
# Vehicle vehicle_6 broadcasting message: {'sender': 'vehicle_6', 'current_position': (9, 6), 'future_positions': [(9, 6), (9, 7), (9, 8), (9, 9), (9, 10), (9, 11)], 'priority': 1716927226.506751, 'waiting': False}
# Vehicle vehicle_7 broadcasting message: {'sender': 'vehicle_7', 'current_position': (1, 11), 'future_positions': [(1, 11), (2, 11), (3, 11), (4, 11), (5, 11), (6, 11)], 'priority': 1716927226.0564313, 'waiting': False}
# Vehicle vehicle_8 broadcasting message: {'sender': 'vehicle_8', 'current_position': (9, 1), 'future_positions': [(9, 1), (9, 2), (9, 3), (9, 4), (9, 5), (9, 6)], 'priority': 1716927226.0564387, 'waiting': False}
# Vehicle vehicle_south_to_north broadcasting message: {'sender': 'vehicle_south_to_north', 'current_position': (11, 3), 'future_positions': [(11, 3), (11, 2), (11, 1), (11, 0), (11, -1), (11, -2)], 'priority': 1716927241.5099523, 'waiting': False}
# Vehicle vehicle_2 broadcasting message: {'sender': 'vehicle_2', 'current_position': (11, 9), 'future_positions': [(11, 9), (11, 8), (11, 7), (11, 6), (11, 5), (11, 4)], 'priority': 1716927227.937944, 'waiting': True}
# Vehicle vehicle_3 broadcasting message: {'sender': 'vehicle_3', 'current_position': (9, 9), 'future_positions': [(9, 9), (8, 9), (7, 9), (6, 9), (5, 9), (4, 9)], 'priority': 1716927227.9379447, 'waiting': True}
# Vehicle vehicle_4 broadcasting message: {'sender': 'vehicle_4', 'current_position': (9, 11), 'future_positions': [(9, 11), (9, 12), (9, 13), (9, 14), (9, 15), (9, 16)], 'priority': 1716927229.0490587, 'waiting': True}
# Vehicle vehicle_5 broadcasting message: {'sender': 'vehicle_5', 'current_position': (14, 9), 'future_positions': [(14, 9), (13, 9), (12, 9), (11, 9), (10, 9), (9, 9)], 'priority': 1716927226.0305526, 'waiting': True}
# Vehicle vehicle_6 broadcasting message: {'sender': 'vehicle_6', 'current_position': (9, 6), 'future_positions': [(9, 6), (9, 7), (9, 8), (9, 9), (9, 10), (9, 11)], 'priority': 1716927226.5067499, 'waiting': True}
# Vehicle vehicle_7 broadcasting message: {'sender': 'vehicle_7', 'current_position': (1, 11), 'future_positions': [(1, 11), (2, 11), (3, 11), (4, 11), (5, 11), (6, 11)], 'priority': 1716927226.0564373, 'waiting': False}
# Vehicle vehicle_8 broadcasting message: {'sender': 'vehicle_8', 'current_position': (9, 1), 'future_positions': [(9, 1), (9, 2), (9, 3), (9, 4), (9, 5), (9, 6)], 'priority': 1716927226.0564365, 'waiting': True}
# Vehicle vehicle_south_to_north broadcasting message: {'sender': 'vehicle_south_to_north', 'current_position': (11, 2), 'future_positions': [(11, 2), (11, 1), (11, 0), (11, -1), (11, -2), (11, -3)], 'priority': 1716927249.8432856, 'waiting': False}
# Vehicle vehicle_2 broadcasting message: {'sender': 'vehicle_2', 'current_position': (11, 8), 'future_positions': [(11, 8), (11, 7), (11, 6), (11, 5), (11, 4), (11, 3)], 'priority': 1716927229.049063, 'waiting': False}
# Vehicle vehicle_3 broadcasting message: {'sender': 'vehicle_3', 'current_position': (8, 9), 'future_positions': [(8, 9), (7, 9), (6, 9), (5, 9), (4, 9), (3, 9)], 'priority': 1716927229.0490549, 'waiting': False}
# Vehicle vehicle_4 broadcasting message: {'sender': 'vehicle_4', 'current_position': (9, 12), 'future_positions': [(9, 12), (9, 13), (9, 14), (9, 15), (9, 16), (9, 17)], 'priority': 1716927230.4379506, 'waiting': False}
# Vehicle vehicle_5 broadcasting message: {'sender': 'vehicle_5', 'current_position': (13, 9), 'future_positions': [(13, 9), (12, 9), (11, 9), (10, 9), (9, 9), (8, 9)], 'priority': 1716927226.5067506, 'waiting': False}
# Vehicle vehicle_6 broadcasting message: {'sender': 'vehicle_6', 'current_position': (9, 7), 'future_positions': [(9, 7), (9, 8), (9, 9), (9, 10), (9, 11), (9, 12)], 'priority': 1716927227.056199, 'waiting': False}
# Vehicle vehicle_7 broadcasting message: {'sender': 'vehicle_7', 'current_position': (2, 11), 'future_positions': [(2, 11), (3, 11), (4, 11), (5, 11), (6, 11), (7, 11)], 'priority': 1716927226.34883, 'waiting': False}
# Vehicle vehicle_8 broadcasting message: {'sender': 'vehicle_8', 'current_position': (9, 2), 'future_positions': [(9, 2), (9, 3), (9, 4), (9, 5), (9, 6), (9, 7)], 'priority': 1716927226.3488317, 'waiting': False}
# Vehicle vehicle_south_to_north broadcasting message: {'sender': 'vehicle_south_to_north', 'current_position': (11, 2), 'future_positions': [(11, 2), (11, 1), (11, 0), (11, -1), (11, -2), (11, -3)], 'priority': 1716927249.8432858, 'waiting': False}
# Vehicle vehicle_2 broadcasting message: {'sender': 'vehicle_2', 'current_position': (11, 8), 'future_positions': [(11, 8), (11, 7), (11, 6), (11, 5), (11, 4), (11, 3)], 'priority': 1716927229.0490584, 'waiting': False}
# Vehicle vehicle_3 broadcasting message: {'sender': 'vehicle_3', 'current_position': (8, 9), 'future_positions': [(8, 9), (7, 9), (6, 9), (5, 9), (4, 9), (3, 9)], 'priority': 1716927229.0490634, 'waiting': True}
# Vehicle vehicle_4 broadcasting message: {'sender': 'vehicle_4', 'current_position': (9, 12), 'future_positions': [(9, 12), (9, 13), (9, 14), (9, 15), (9, 16), (9, 17)], 'priority': 1716927230.437948, 'waiting': True}
# Vehicle vehicle_5 broadcasting message: {'sender': 'vehicle_5', 'current_position': (13, 9), 'future_positions': [(13, 9), (12, 9), (11, 9), (10, 9), (9, 9), (8, 9)], 'priority': 1716927226.5067434, 'waiting': True}
# Vehicle vehicle_6 broadcasting message: {'sender': 'vehicle_6', 'current_position': (9, 7), 'future_positions': [(9, 7), (9, 8), (9, 9), (9, 10), (9, 11), (9, 12)], 'priority': 1716927227.0562005, 'waiting': True}
# Vehicle vehicle_7 broadcasting message: {'sender': 'vehicle_7', 'current_position': (2, 11), 'future_positions': [(2, 11), (3, 11), (4, 11), (5, 11), (6, 11), (7, 11)], 'priority': 1716927226.3488371, 'waiting': False}
# Vehicle vehicle_8 broadcasting message: {'sender': 'vehicle_8', 'current_position': (9, 2), 'future_positions': [(9, 2), (9, 3), (9, 4), (9, 5), (9, 6), (9, 7)], 'priority': 1716927226.348828, 'waiting': True}
# Vehicle vehicle_south_to_north broadcasting message: {'sender': 'vehicle_south_to_north', 'current_position': (11, 1), 'future_positions': [(11, 1), (11, 0), (11, -1), (11, -2), (11, -3), (11, -4)], 'priority': 1716927266.509956, 'waiting': False}
# Vehicle vehicle_2 broadcasting message: {'sender': 'vehicle_2', 'current_position': (11, 7), 'future_positions': [(11, 7), (11, 6), (11, 5), (11, 4), (11, 3), (11, 2)], 'priority': 1716927230.4379523, 'waiting': False}
# Vehicle vehicle_3 broadcasting message: {'sender': 'vehicle_3', 'current_position': (7, 9), 'future_positions': [(7, 9), (6, 9), (5, 9), (4, 9), (3, 9), (2, 9)], 'priority': 1716927230.437948, 'waiting': False}
# Vehicle vehicle_4 broadcasting message: {'sender': 'vehicle_4', 'current_position': (9, 13), 'future_positions': [(9, 13), (9, 14), (9, 15), (9, 16), (9, 17), (9, 18)], 'priority': 1716927232.2236621, 'waiting': False}
# Vehicle vehicle_5 broadcasting message: {'sender': 'vehicle_5', 'current_position': (12, 9), 'future_positions': [(12, 9), (11, 9), (10, 9), (9, 9), (8, 9), (7, 9)], 'priority': 1716927227.0561938, 'waiting': False}
# Vehicle vehicle_6 broadcasting message: {'sender': 'vehicle_6', 'current_position': (9, 8), 'future_positions': [(9, 8), (9, 9), (9, 10), (9, 11), (9, 12), (9, 13)], 'priority': 1716927227.6972246, 'waiting': False}
# Vehicle vehicle_7 broadcasting message: {'sender': 'vehicle_7', 'current_position': (3, 11), 'future_positions': [(3, 11), (4, 11), (5, 11), (6, 11), (7, 11), (8, 11)], 'priority': 1716927226.6756322, 'waiting': False}
# Vehicle vehicle_8 broadcasting message: {'sender': 'vehicle_8', 'current_position': (9, 3), 'future_positions': [(9, 3), (9, 4), (9, 5), (9, 6), (9, 7), (9, 8)], 'priority': 1716927226.675628, 'waiting': False}
# Vehicle vehicle_south_to_north broadcasting message: {'sender': 'vehicle_south_to_north', 'current_position': (11, 1), 'future_positions': [(11, 1), (11, 0), (11, -1), (11, -2), (11, -3), (11, -4)], 'priority': 1716927266.5099561, 'waiting': False}
# Vehicle vehicle_2 broadcasting message: {'sender': 'vehicle_2', 'current_position': (11, 7), 'future_positions': [(11, 7), (11, 6), (11, 5), (11, 4), (11, 3), (11, 2)], 'priority': 1716927230.437946, 'waiting': False}
# Vehicle vehicle_3 broadcasting message: {'sender': 'vehicle_3', 'current_position': (7, 9), 'future_positions': [(7, 9), (6, 9), (5, 9), (4, 9), (3, 9), (2, 9)], 'priority': 1716927230.4379492, 'waiting': True}
# Vehicle vehicle_4 broadcasting message: {'sender': 'vehicle_4', 'current_position': (9, 13), 'future_positions': [(9, 13), (9, 14), (9, 15), (9, 16), (9, 17), (9, 18)], 'priority': 1716927232.2236664, 'waiting': True}
# Vehicle vehicle_5 broadcasting message: {'sender': 'vehicle_5', 'current_position': (12, 9), 'future_positions': [(12, 9), (11, 9), (10, 9), (9, 9), (8, 9), (7, 9)], 'priority': 1716927227.0562007, 'waiting': True}
# Vehicle vehicle_6 broadcasting message: {'sender': 'vehicle_6', 'current_position': (9, 8), 'future_positions': [(9, 8), (9, 9), (9, 10), (9, 11), (9, 12), (9, 13)], 'priority': 1716927227.6972225, 'waiting': True}
# Vehicle vehicle_7 broadcasting message: {'sender': 'vehicle_7', 'current_position': (3, 11), 'future_positions': [(3, 11), (4, 11), (5, 11), (6, 11), (7, 11), (8, 11)], 'priority': 1716927226.6756291, 'waiting': False}
# Vehicle vehicle_8 broadcasting message: {'sender': 'vehicle_8', 'current_position': (9, 3), 'future_positions': [(9, 3), (9, 4), (9, 5), (9, 6), (9, 7), (9, 8)], 'priority': 1716927226.6756287, 'waiting': True}
# Vehicle vehicle_2 broadcasting message: {'sender': 'vehicle_2', 'current_position': (11, 6), 'future_positions': [(11, 6), (11, 5), (11, 4), (11, 3), (11, 2), (11, 1)], 'priority': 1716927232.2236676, 'waiting': False}
# Vehicle vehicle_3 broadcasting message: {'sender': 'vehicle_3', 'current_position': (6, 9), 'future_positions': [(6, 9), (5, 9), (4, 9), (3, 9), (2, 9), (1, 9)], 'priority': 1716927232.2236626, 'waiting': False}
# Vehicle vehicle_4 broadcasting message: {'sender': 'vehicle_4', 'current_position': (9, 14), 'future_positions': [(9, 14), (9, 15), (9, 16), (9, 17), (9, 18), (9, 19)], 'priority': 1716927234.6046135, 'waiting': False}
# Vehicle vehicle_5 broadcasting message: {'sender': 'vehicle_5', 'current_position': (11, 9), 'future_positions': [(11, 9), (10, 9), (9, 9), (8, 9), (7, 9), (6, 9)], 'priority': 1716927227.6972268, 'waiting': False}
# Vehicle vehicle_6 broadcasting message: {'sender': 'vehicle_6', 'current_position': (9, 9), 'future_positions': [(9, 9), (9, 10), (9, 11), (9, 12), (9, 13), (9, 14)], 'priority': 1716927228.4547956, 'waiting': False}
# Vehicle vehicle_7 broadcasting message: {'sender': 'vehicle_7', 'current_position': (4, 11), 'future_positions': [(4, 11), (5, 11), (6, 11), (7, 11), (8, 11), (9, 11)], 'priority': 1716927227.0432775, 'waiting': False}
# Vehicle vehicle_8 broadcasting message: {'sender': 'vehicle_8', 'current_position': (9, 4), 'future_positions': [(9, 4), (9, 5), (9, 6), (9, 7), (9, 8), (9, 9)], 'priority': 1716927227.043273, 'waiting': False}
# Vehicle vehicle_2 broadcasting message: {'sender': 'vehicle_2', 'current_position': (11, 6), 'future_positions': [(11, 6), (11, 5), (11, 4), (11, 3), (11, 2), (11, 1)], 'priority': 1716927232.2236679, 'waiting': False}
# Vehicle vehicle_3 broadcasting message: {'sender': 'vehicle_3', 'current_position': (6, 9), 'future_positions': [(6, 9), (5, 9), (4, 9), (3, 9), (2, 9), (1, 9)], 'priority': 1716927232.2236667, 'waiting': True}
# Vehicle vehicle_4 broadcasting message: {'sender': 'vehicle_4', 'current_position': (9, 14), 'future_positions': [(9, 14), (9, 15), (9, 16), (9, 17), (9, 18), (9, 19)], 'priority': 1716927234.604614, 'waiting': True}
# Vehicle vehicle_5 broadcasting message: {'sender': 'vehicle_5', 'current_position': (11, 9), 'future_positions': [(11, 9), (10, 9), (9, 9), (8, 9), (7, 9), (6, 9)], 'priority': 1716927227.6972194, 'waiting': True}
# Vehicle vehicle_6 broadcasting message: {'sender': 'vehicle_6', 'current_position': (9, 9), 'future_positions': [(9, 9), (9, 10), (9, 11), (9, 12), (9, 13), (9, 14)], 'priority': 1716927228.4547937, 'waiting': True}
# Vehicle vehicle_7 broadcasting message: {'sender': 'vehicle_7', 'current_position': (4, 11), 'future_positions': [(4, 11), (5, 11), (6, 11), (7, 11), (8, 11), (9, 11)], 'priority': 1716927227.0432777, 'waiting': True}
# Vehicle vehicle_8 broadcasting message: {'sender': 'vehicle_8', 'current_position': (9, 4), 'future_positions': [(9, 4), (9, 5), (9, 6), (9, 7), (9, 8), (9, 9)], 'priority': 1716927227.0432758, 'waiting': True}
# Vehicle vehicle_2 broadcasting message: {'sender': 'vehicle_2', 'current_position': (11, 5), 'future_positions': [(11, 5), (11, 4), (11, 3), (11, 2), (11, 1), (11, 0)], 'priority': 1716927234.6046174, 'waiting': False}
# Vehicle vehicle_3 broadcasting message: {'sender': 'vehicle_3', 'current_position': (5, 9), 'future_positions': [(5, 9), (4, 9), (3, 9), (2, 9), (1, 9), (0, 9)], 'priority': 1716927234.604615, 'waiting': False}
# Vehicle vehicle_4 broadcasting message: {'sender': 'vehicle_4', 'current_position': (9, 15), 'future_positions': [(9, 15), (9, 16), (9, 17), (9, 18), (9, 19), (9, 20)], 'priority': 1716927237.9379463, 'waiting': False}
# Vehicle vehicle_5 broadcasting message: {'sender': 'vehicle_5', 'current_position': (11, 9), 'future_positions': [(11, 9), (10, 9), (9, 9), (8, 9), (7, 9), (6, 9)], 'priority': 1716927227.6972208, 'waiting': True}
# Vehicle vehicle_6 broadcasting message: {'sender': 'vehicle_6', 'current_position': (9, 10), 'future_positions': [(9, 10), (9, 11), (9, 12), (9, 13), (9, 14), (9, 15)], 'priority': 1716927229.363888, 'waiting': False}
# Vehicle vehicle_7 broadcasting message: {'sender': 'vehicle_7', 'current_position': (5, 11), 'future_positions': [(5, 11), (6, 11), (7, 11), (8, 11), (9, 11), (10, 11)], 'priority': 1716927227.4599483, 'waiting': False}
# Vehicle vehicle_8 broadcasting message: {'sender': 'vehicle_8', 'current_position': (9, 5), 'future_positions': [(9, 5), (9, 6), (9, 7), (9, 8), (9, 9), (9, 10)], 'priority': 1716927227.4599402, 'waiting': False}
# Vehicle vehicle_8 broadcasting message: {'sender': 'vehicle_8', 'current_position': (0, 11), 'future_positions': [(0, 11), (1, 11), (2, 11), (3, 11), (4, 11), (5, 11)], 'priority': 1716927227.236173, 'waiting': False}
# Vehicle vehicle_9 broadcasting message: {'sender': 'vehicle_9', 'current_position': (11, 19), 'future_positions': [(11, 19), (11, 18), (11, 17), (11, 16), (11, 15), (11, 14)], 'priority': 1716927227.2361672, 'waiting': False}
# Vehicle vehicle_10 broadcasting message: {'sender': 'vehicle_10', 'current_position': (19, 9), 'future_positions': [(19, 9), (18, 9), (17, 9), (16, 9), (15, 9), (14, 9)], 'priority': 1716927227.2361748, 'waiting': False}
# Vehicle vehicle_2 broadcasting message: {'sender': 'vehicle_2', 'current_position': (11, 5), 'future_positions': [(11, 5), (11, 4), (11, 3), (11, 2), (11, 1), (11, 0)], 'priority': 1716927234.6046197, 'waiting': False}
# Vehicle vehicle_3 broadcasting message: {'sender': 'vehicle_3', 'current_position': (5, 9), 'future_positions': [(5, 9), (4, 9), (3, 9), (2, 9), (1, 9), (0, 9)], 'priority': 1716927234.6046128, 'waiting': False}
# Vehicle vehicle_4 broadcasting message: {'sender': 'vehicle_4', 'current_position': (9, 15), 'future_positions': [(9, 15), (9, 16), (9, 17), (9, 18), (9, 19), (9, 20)], 'priority': 1716927237.9379497, 'waiting': True}
# Vehicle vehicle_5 broadcasting message: {'sender': 'vehicle_5', 'current_position': (11, 9), 'future_positions': [(11, 9), (10, 9), (9, 9), (8, 9), (7, 9), (6, 9)], 'priority': 1716927227.6972268, 'waiting': True}
# Vehicle vehicle_6 broadcasting message: {'sender': 'vehicle_6', 'current_position': (9, 10), 'future_positions': [(9, 10), (9, 11), (9, 12), (9, 13), (9, 14), (9, 15)], 'priority': 1716927229.3638937, 'waiting': True}
# Vehicle vehicle_7 broadcasting message: {'sender': 'vehicle_7', 'current_position': (5, 11), 'future_positions': [(5, 11), (6, 11), (7, 11), (8, 11), (9, 11), (10, 11)], 'priority': 1716927227.4599423, 'waiting': True}
# Vehicle vehicle_8 broadcasting message: {'sender': 'vehicle_8', 'current_position': (9, 5), 'future_positions': [(9, 5), (9, 6), (9, 7), (9, 8), (9, 9), (9, 10)], 'priority': 1716927227.4599395, 'waiting': True}
# Vehicle vehicle_8 broadcasting message: {'sender': 'vehicle_8', 'current_position': (0, 11), 'future_positions': [(0, 11), (1, 11), (2, 11), (3, 11), (4, 11), (5, 11)], 'priority': 1716927227.2361658, 'waiting': True}
# Vehicle vehicle_9 broadcasting message: {'sender': 'vehicle_9', 'current_position': (11, 19), 'future_positions': [(11, 19), (11, 18), (11, 17), (11, 16), (11, 15), (11, 14)], 'priority': 1716927227.2361693, 'waiting': False}
# Vehicle vehicle_10 broadcasting message: {'sender': 'vehicle_10', 'current_position': (19, 9), 'future_positions': [(19, 9), (18, 9), (17, 9), (16, 9), (15, 9), (14, 9)], 'priority': 1716927227.2361746, 'waiting': False}
# Vehicle vehicle_2 broadcasting message: {'sender': 'vehicle_2', 'current_position': (11, 4), 'future_positions': [(11, 4), (11, 3), (11, 2), (11, 1), (11, 0), (11, -1)], 'priority': 1716927237.9379487, 'waiting': False}
# Vehicle vehicle_3 broadcasting message: {'sender': 'vehicle_3', 'current_position': (4, 9), 'future_positions': [(4, 9), (3, 9), (2, 9), (1, 9), (0, 9), (-1, 9)], 'priority': 1716927237.9379497, 'waiting': False}
# Vehicle vehicle_4 broadcasting message: {'sender': 'vehicle_4', 'current_position': (9, 16), 'future_positions': [(9, 16), (9, 17), (9, 18), (9, 19), (9, 20), (9, 21)], 'priority': 1716927242.9379516, 'waiting': False}
# Vehicle vehicle_5 broadcasting message: {'sender': 'vehicle_5', 'current_position': (10, 9), 'future_positions': [(10, 9), (9, 9), (8, 9), (7, 9), (6, 9), (5, 9)], 'priority': 1716927228.4547942, 'waiting': False}
# Vehicle vehicle_6 broadcasting message: {'sender': 'vehicle_6', 'current_position': (9, 11), 'future_positions': [(9, 11), (9, 12), (9, 13), (9, 14), (9, 15), (9, 16)], 'priority': 1716927230.474999, 'waiting': False}
# Vehicle vehicle_7 broadcasting message: {'sender': 'vehicle_7', 'current_position': (6, 11), 'future_positions': [(6, 11), (7, 11), (8, 11), (9, 11), (10, 11), (11, 11)], 'priority': 1716927227.9361358, 'waiting': False}
# Vehicle vehicle_8 broadcasting message: {'sender': 'vehicle_8', 'current_position': (9, 6), 'future_positions': [(9, 6), (9, 7), (9, 8), (9, 9), (9, 10), (9, 11)], 'priority': 1716927227.9361377, 'waiting': False}
# Vehicle vehicle_8 broadcasting message: {'sender': 'vehicle_8', 'current_position': (1, 11), 'future_positions': [(1, 11), (2, 11), (3, 11), (4, 11), (5, 11), (6, 11)], 'priority': 1716927227.4993248, 'waiting': False}
# ...
# Vehicle vehicle_9 broadcasting message: {'sender': 'vehicle_9', 'current_position': (14, 9), 'future_positions': [(14, 9), (13, 9), (12, 9), (11, 9), (10, 9), (9, 9)], 'priority': 1716927408.020543, 'waiting': True}
# Vehicle vehicle_9 broadcasting message: {'sender': 'vehicle_9', 'current_position': (11, 19), 'future_positions': [(11, 19), (11, 18), (11, 17), (11, 16), (11, 15), (11, 14)], 'priority': 1716927408.1896515, 'waiting': True}
# Vehicle vehicle_6 broadcasting message: {'sender': 'vehicle_6', 'current_position': (11, 5), 'future_positions': [(11, 5), (11, 4), (11, 3), (11, 2), (11, 1), (11, 0)], 'priority': 1716927413.9507487, 'waiting': False}
# Vehicle vehicle_7 broadcasting message: {'sender': 'vehicle_7', 'current_position': (3, 9), 'future_positions': [(3, 9), (2, 9), (1, 9), (0, 9), (-1, 9), (-2, 9)], 'priority': 1716927422.2840767, 'waiting': False}
# Vehicle vehicle_5 broadcasting message: {'sender': 'vehicle_5', 'current_position': (9, 10), 'future_positions': [(9, 10), (9, 11), (9, 12), (9, 13), (9, 14), (9, 15)], 'priority': 1716927409.066128, 'waiting': True}
# Vehicle vehicle_6 broadcasting message: {'sender': 'vehicle_6', 'current_position': (10, 11), 'future_positions': [(10, 11), (11, 11), (12, 11), (13, 11), (14, 11), (15, 11)], 'priority': 1716927409.0661283, 'waiting': False}
# Vehicle vehicle_7 broadcasting message: {'sender': 'vehicle_7', 'current_position': (11, 8), 'future_positions': [(11, 8), (11, 7), (11, 6), (11, 5), (11, 4), (11, 3)], 'priority': 1716927410.1772432, 'waiting': False}
# Vehicle vehicle_7 broadcasting message: {'sender': 'vehicle_7', 'current_position': (9, 6), 'future_positions': [(9, 6), (9, 7), (9, 8), (9, 9), (9, 10), (9, 11)], 'priority': 1716927408.4967334, 'waiting': False}
# Vehicle vehicle_8 broadcasting message: {'sender': 'vehicle_8', 'current_position': (11, 13), 'future_positions': [(11, 13), (11, 12), (11, 11), (11, 10), (11, 9), (11, 8)], 'priority': 1716927408.4967408, 'waiting': False}
# Vehicle vehicle_9 broadcasting message: {'sender': 'vehicle_9', 'current_position': (13, 9), 'future_positions': [(13, 9), (12, 9), (11, 9), (10, 9), (9, 9), (8, 9)], 'priority': 1716927408.4967363, 'waiting': False}
# Vehicle vehicle_9 broadcasting message: {'sender': 'vehicle_9', 'current_position': (11, 18), 'future_positions': [(11, 18), (11, 17), (11, 16), (11, 15), (11, 14), (11, 13)], 'priority': 1716927408.4528127, 'waiting': False}
# Vehicle vehicle_6 broadcasting message: {'sender': 'vehicle_6', 'current_position': (11, 5), 'future_positions': [(11, 5), (11, 4), (11, 3), (11, 2), (11, 1), (11, 0)], 'priority': 1716927413.950752, 'waiting': True}
# Vehicle vehicle_7 broadcasting message: {'sender': 'vehicle_7', 'current_position': (3, 9), 'future_positions': [(3, 9), (2, 9), (1, 9), (0, 9), (-1, 9), (-2, 9)], 'priority': 1716927422.2840784, 'waiting': False}
# Vehicle vehicle_5 broadcasting message: {'sender': 'vehicle_5', 'current_position': (9, 10), 'future_positions': [(9, 10), (9, 11), (9, 12), (9, 13), (9, 14), (9, 15)], 'priority': 1716927409.066132, 'waiting': True}
# Vehicle vehicle_6 broadcasting message: {'sender': 'vehicle_6', 'current_position': (10, 11), 'future_positions': [(10, 11), (11, 11), (12, 11), (13, 11), (14, 11), (15, 11)], 'priority': 1716927409.0661294, 'waiting': True}
# Vehicle vehicle_7 broadcasting message: {'sender': 'vehicle_7', 'current_position': (11, 8), 'future_positions': [(11, 8), (11, 7), (11, 6), (11, 5), (11, 4), (11, 3)], 'priority': 1716927410.1772413, 'waiting': True}
# Vehicle vehicle_7 broadcasting message: {'sender': 'vehicle_7', 'current_position': (9, 6), 'future_positions': [(9, 6), (9, 7), (9, 8), (9, 9), (9, 10), (9, 11)], 'priority': 1716927408.4967413, 'waiting': True}
# Vehicle vehicle_8 broadcasting message: {'sender': 'vehicle_8', 'current_position': (11, 13), 'future_positions': [(11, 13), (11, 12), (11, 11), (11, 10), (11, 9), (11, 8)], 'priority': 1716927408.4967349, 'waiting': True}
# Vehicle vehicle_9 broadcasting message: {'sender': 'vehicle_9', 'current_position': (13, 9), 'future_positions': [(13, 9), (12, 9), (11, 9), (10, 9), (9, 9), (8, 9)], 'priority': 1716927408.4967346, 'waiting': True}
# Vehicle vehicle_9 broadcasting message: {'sender': 'vehicle_9', 'current_position': (11, 18), 'future_positions': [(11, 18), (11, 17), (11, 16), (11, 15), (11, 14), (11, 13)], 'priority': 1716927408.4528139, 'waiting': True}
# Vehicle vehicle_6 broadcasting message: {'sender': 'vehicle_6', 'current_position': (11, 4), 'future_positions': [(11, 4), (11, 3), (11, 2), (11, 1), (11, 0), (11, -1)], 'priority': 1716927417.284084, 'waiting': False}
# Vehicle vehicle_7 broadcasting message: {'sender': 'vehicle_7', 'current_position': (2, 9), 'future_positions': [(2, 9), (1, 9), (0, 9), (-1, 9), (-2, 9), (-3, 9)], 'priority': 1716927430.617411, 'waiting': False}
# Vehicle vehicle_5 broadcasting message: {'sender': 'vehicle_5', 'current_position': (9, 11), 'future_positions': [(9, 11), (9, 12), (9, 13), (9, 14), (9, 15), (9, 16)], 'priority': 1716927410.1772428, 'waiting': False}
# Vehicle vehicle_6 broadcasting message: {'sender': 'vehicle_6', 'current_position': (11, 11), 'future_positions': [(11, 11), (12, 11), (13, 11), (14, 11), (15, 11), (16, 11)], 'priority': 1716927410.1772394, 'waiting': False}
# Vehicle vehicle_7 broadcasting message: {'sender': 'vehicle_7', 'current_position': (11, 7), 'future_positions': [(11, 7), (11, 6), (11, 5), (11, 4), (11, 3), (11, 2)], 'priority': 1716927411.5661287, 'waiting': False}
# Vehicle vehicle_7 broadcasting message: {'sender': 'vehicle_7', 'current_position': (9, 7), 'future_positions': [(9, 7), (9, 8), (9, 9), (9, 10), (9, 11), (9, 12)], 'priority': 1716927409.046192, 'waiting': False}
# Vehicle vehicle_8 broadcasting message: {'sender': 'vehicle_8', 'current_position': (11, 13), 'future_positions': [(11, 13), (11, 12), (11, 11), (11, 10), (11, 9), (11, 8)], 'priority': 1716927408.4967406, 'waiting': True}
# Vehicle vehicle_9 broadcasting message: {'sender': 'vehicle_9', 'current_position': (12, 9), 'future_positions': [(12, 9), (11, 9), (10, 9), (9, 9), (8, 9), (7, 9)], 'priority': 1716927409.0461893, 'waiting': False}
# Vehicle vehicle_9 broadcasting message: {'sender': 'vehicle_9', 'current_position': (11, 17), 'future_positions': [(11, 17), (11, 16), (11, 15), (11, 14), (11, 13), (11, 12)], 'priority': 1716927408.7452047, 'waiting': False}
# Vehicle vehicle_6 broadcasting message: {'sender': 'vehicle_6', 'current_position': (11, 4), 'future_positions': [(11, 4), (11, 3), (11, 2), (11, 1), (11, 0), (11, -1)], 'priority': 1716927417.2840805, 'waiting': True}
# Vehicle vehicle_7 broadcasting message: {'sender': 'vehicle_7', 'current_position': (2, 9), 'future_positions': [(2, 9), (1, 9), (0, 9), (-1, 9), (-2, 9), (-3, 9)], 'priority': 1716927430.617419, 'waiting': False}
# Vehicle vehicle_5 broadcasting message: {'sender': 'vehicle_5', 'current_position': (9, 11), 'future_positions': [(9, 11), (9, 12), (9, 13), (9, 14), (9, 15), (9, 16)], 'priority': 1716927410.177237, 'waiting': True}
# Vehicle vehicle_6 broadcasting message: {'sender': 'vehicle_6', 'current_position': (11, 11), 'future_positions': [(11, 11), (12, 11), (13, 11), (14, 11), (15, 11), (16, 11)], 'priority': 1716927410.1772394, 'waiting': True}
# Vehicle vehicle_7 broadcasting message: {'sender': 'vehicle_7', 'current_position': (11, 7), 'future_positions': [(11, 7), (11, 6), (11, 5), (11, 4), (11, 3), (11, 2)], 'priority': 1716927411.566129, 'waiting': True}
# Vehicle vehicle_7 broadcasting message: {'sender': 'vehicle_7', 'current_position': (9, 7), 'future_positions': [(9, 7), (9, 8), (9, 9), (9, 10), (9, 11), (9, 12)], 'priority': 1716927409.0461843, 'waiting': True}
# Vehicle vehicle_8 broadcasting message: {'sender': 'vehicle_8', 'current_position': (11, 13), 'future_positions': [(11, 13), (11, 12), (11, 11), (11, 10), (11, 9), (11, 8)], 'priority': 1716927408.496738, 'waiting': True}
# Vehicle vehicle_9 broadcasting message: {'sender': 'vehicle_9', 'current_position': (12, 9), 'future_positions': [(12, 9), (11, 9), (10, 9), (9, 9), (8, 9), (7, 9)], 'priority': 1716927409.0461888, 'waiting': True}
# Vehicle vehicle_9 broadcasting message: {'sender': 'vehicle_9', 'current_position': (11, 17), 'future_positions': [(11, 17), (11, 16), (11, 15), (11, 14), (11, 13), (11, 12)], 'priority': 1716927408.7452116, 'waiting': True}
# Vehicle vehicle_6 broadcasting message: {'sender': 'vehicle_6', 'current_position': (11, 3), 'future_positions': [(11, 3), (11, 2), (11, 1), (11, 0), (11, -1), (11, -2)], 'priority': 1716927422.2840772, 'waiting': False}
# Vehicle vehicle_7 broadcasting message: {'sender': 'vehicle_7', 'current_position': (1, 9), 'future_positions': [(1, 9), (0, 9), (-1, 9), (-2, 9), (-3, 9), (-4, 9)], 'priority': 1716927447.2840858, 'waiting': False}
# Vehicle vehicle_5 broadcasting message: {'sender': 'vehicle_5', 'current_position': (9, 12), 'future_positions': [(9, 12), (9, 13), (9, 14), (9, 15), (9, 16), (9, 17)], 'priority': 1716927411.5661352, 'waiting': False}
# Vehicle vehicle_6 broadcasting message: {'sender': 'vehicle_6', 'current_position': (12, 11), 'future_positions': [(12, 11), (13, 11), (14, 11), (15, 11), (16, 11), (17, 11)], 'priority': 1716927411.566132, 'waiting': False}
# Vehicle vehicle_7 broadcasting message: {'sender': 'vehicle_7', 'current_position': (11, 6), 'future_positions': [(11, 6), (11, 5), (11, 4), (11, 3), (11, 2), (11, 1)], 'priority': 1716927413.3518467, 'waiting': False}
# Vehicle vehicle_7 broadcasting message: {'sender': 'vehicle_7', 'current_position': (9, 8), 'future_positions': [(9, 8), (9, 9), (9, 10), (9, 11), (9, 12), (9, 13)], 'priority': 1716927409.6872106, 'waiting': False}
# Vehicle vehicle_8 broadcasting message: {'sender': 'vehicle_8', 'current_position': (11, 12), 'future_positions': [(11, 12), (11, 11), (11, 10), (11, 9), (11, 8), (11, 7)], 'priority': 1716927409.0461867, 'waiting': False}
# Vehicle vehicle_9 broadcasting message: {'sender': 'vehicle_9', 'current_position': (11, 9), 'future_positions': [(11, 9), (10, 9), (9, 9), (8, 9), (7, 9), (6, 9)], 'priority': 1716927409.6872122, 'waiting': False}
# Vehicle vehicle_9 broadcasting message: {'sender': 'vehicle_9', 'current_position': (11, 16), 'future_positions': [(11, 16), (11, 15), (11, 14), (11, 13), (11, 12), (11, 11)], 'priority': 1716927409.0720074, 'waiting': False}
# Vehicle vehicle_6 broadcasting message: {'sender': 'vehicle_6', 'current_position': (11, 3), 'future_positions': [(11, 3), (11, 2), (11, 1), (11, 0), (11, -1), (11, -2)], 'priority': 1716927422.2840784, 'waiting': True}
# Vehicle vehicle_7 broadcasting message: {'sender': 'vehicle_7', 'current_position': (1, 9), 'future_positions': [(1, 9), (0, 9), (-1, 9), (-2, 9), (-3, 9), (-4, 9)], 'priority': 1716927447.2840855, 'waiting': False}
# Vehicle vehicle_5 broadcasting message: {'sender': 'vehicle_5', 'current_position': (9, 12), 'future_positions': [(9, 12), (9, 13), (9, 14), (9, 15), (9, 16), (9, 17)], 'priority': 1716927411.5661268, 'waiting': True}
# Vehicle vehicle_6 broadcasting message: {'sender': 'vehicle_6', 'current_position': (12, 11), 'future_positions': [(12, 11), (13, 11), (14, 11), (15, 11), (16, 11), (17, 11)], 'priority': 1716927411.566131, 'waiting': False}
# Vehicle vehicle_7 broadcasting message: {'sender': 'vehicle_7', 'current_position': (11, 6), 'future_positions': [(11, 6), (11, 5), (11, 4), (11, 3), (11, 2), (11, 1)], 'priority': 1716927413.3518407, 'waiting': True}
# Vehicle vehicle_7 broadcasting message: {'sender': 'vehicle_7', 'current_position': (9, 8), 'future_positions': [(9, 8), (9, 9), (9, 10), (9, 11), (9, 12), (9, 13)], 'priority': 1716927409.6872132, 'waiting': True}
# Vehicle vehicle_8 broadcasting message: {'sender': 'vehicle_8', 'current_position': (11, 12), 'future_positions': [(11, 12), (11, 11), (11, 10), (11, 9), (11, 8), (11, 7)], 'priority': 1716927409.046188, 'waiting': True}
# Vehicle vehicle_9 broadcasting message: {'sender': 'vehicle_9', 'current_position': (11, 9), 'future_positions': [(11, 9), (10, 9), (9, 9), (8, 9), (7, 9), (6, 9)], 'priority': 1716927409.68721, 'waiting': True}
# Vehicle vehicle_9 broadcasting message: {'sender': 'vehicle_9', 'current_position': (11, 16), 'future_positions': [(11, 16), (11, 15), (11, 14), (11, 13), (11, 12), (11, 11)], 'priority': 1716927409.0720015, 'waiting': True}
# Vehicle vehicle_6 broadcasting message: {'sender': 'vehicle_6', 'current_position': (11, 2), 'future_positions': [(11, 2), (11, 1), (11, 0), (11, -1), (11, -2), (11, -3)], 'priority': 1716927430.6174133, 'waiting': False}
# Vehicle vehicle_5 broadcasting message: {'sender': 'vehicle_5', 'current_position': (9, 13), 'future_positions': [(9, 13), (9, 14), (9, 15), (9, 16), (9, 17), (9, 18)], 'priority': 1716927413.3518417, 'waiting': False}
# Vehicle vehicle_6 broadcasting message: {'sender': 'vehicle_6', 'current_position': (13, 11), 'future_positions': [(13, 11), (14, 11), (15, 11), (16, 11), (17, 11), (18, 11)], 'priority': 1716927413.3518422, 'waiting': False}
# Vehicle vehicle_7 broadcasting message: {'sender': 'vehicle_7', 'current_position': (11, 5), 'future_positions': [(11, 5), (11, 4), (11, 3), (11, 2), (11, 1), (11, 0)], 'priority': 1716927415.7327967, 'waiting': False}
# Vehicle vehicle_7 broadcasting message: {'sender': 'vehicle_7', 'current_position': (9, 9), 'future_positions': [(9, 9), (9, 10), (9, 11), (9, 12), (9, 13), (9, 14)], 'priority': 1716927410.4447875, 'waiting': False}
# Vehicle vehicle_8 broadcasting message: {'sender': 'vehicle_8', 'current_position': (11, 12), 'future_positions': [(11, 12), (11, 11), (11, 10), (11, 9), (11, 8), (11, 7)], 'priority': 1716927409.046189, 'waiting': True}
# Vehicle vehicle_9 broadcasting message: {'sender': 'vehicle_9', 'current_position': (11, 9), 'future_positions': [(11, 9), (10, 9), (9, 9), (8, 9), (7, 9), (6, 9)], 'priority': 1716927409.6872153, 'waiting': True}
# Vehicle vehicle_9 broadcasting message: {'sender': 'vehicle_9', 'current_position': (11, 15), 'future_positions': [(11, 15), (11, 14), (11, 13), (11, 12), (11, 11), (11, 10)], 'priority': 1716927409.4396484, 'waiting': False}
# Vehicle vehicle_6 broadcasting message: {'sender': 'vehicle_6', 'current_position': (11, 2), 'future_positions': [(11, 2), (11, 1), (11, 0), (11, -1), (11, -2), (11, -3)], 'priority': 1716927430.6174097, 'waiting': True}
# Vehicle vehicle_5 broadcasting message: {'sender': 'vehicle_5', 'current_position': (9, 13), 'future_positions': [(9, 13), (9, 14), (9, 15), (9, 16), (9, 17), (9, 18)], 'priority': 1716927413.3518434, 'waiting': True}
# Vehicle vehicle_6 broadcasting message: {'sender': 'vehicle_6', 'current_position': (13, 11), 'future_positions': [(13, 11), (14, 11), (15, 11), (16, 11), (17, 11), (18, 11)], 'priority': 1716927413.3518488, 'waiting': False}
# Vehicle vehicle_7 broadcasting message: {'sender': 'vehicle_7', 'current_position': (11, 5), 'future_positions': [(11, 5), (11, 4), (11, 3), (11, 2), (11, 1), (11, 0)], 'priority': 1716927415.732802, 'waiting': True}
# Vehicle vehicle_7 broadcasting message: {'sender': 'vehicle_7', 'current_position': (9, 9), 'future_positions': [(9, 9), (9, 10), (9, 11), (9, 12), (9, 13), (9, 14)], 'priority': 1716927410.4447858, 'waiting': True}
# Vehicle vehicle_8 broadcasting message: {'sender': 'vehicle_8', 'current_position': (11, 12), 'future_positions': [(11, 12), (11, 11), (11, 10), (11, 9), (11, 8), (11, 7)], 'priority': 1716927409.0461843, 'waiting': True}
# Vehicle vehicle_9 broadcasting message: {'sender': 'vehicle_9', 'current_position': (11, 9), 'future_positions': [(11, 9), (10, 9), (9, 9), (8, 9), (7, 9), (6, 9)], 'priority': 1716927409.687211, 'waiting': True}
# Vehicle vehicle_9 broadcasting message: {'sender': 'vehicle_9', 'current_position': (11, 15), 'future_positions': [(11, 15), (11, 14), (11, 13), (11, 12), (11, 11), (11, 10)], 'priority': 1716927409.4396524, 'waiting': True}
# KeyboardInterrupt
